# %%
import requests
import time

def get_uniprot_ids(chembl_id):
    """Fetch UniProt IDs for a given ChEMBL ID"""
    url = f"https://www.ebi.ac.uk/chembl/api/data/target/{chembl_id}.json"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        
        uniprot_ids = []


        if 'target_components' in data:
            #print("algo")
            for component in data['target_components']:
                #print(component)
                if 'target_component_xrefs' in component:
                    for xref in component['target_component_xrefs']:
                        #print(xref)
                        if xref['xref_src_db'] == 'UniProt':
                            uniprot_ids.append(xref['xref_id'])
                            
        
        return uniprot_ids
    except:
        return []
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# # Read ChEMBL IDs from input file
# with open('xfp_chembls.txt', 'r') as f:
#     chembl_ids = [line.strip() for line in f if line.strip()]

# # Read ChEMBL IDs from input file
# with open('ecfp_chembls.txt', 'r') as f:
#     chembl_ids2 = [line.strip() for line in f if line.strip()]

# chembl_ids = chembl_ids + chembl_ids2

# %%
with open('ppb_chembl_ids.txt', 'r') as f:
    chembl_ids = [line.strip() for line in f if line.strip()]

# %%
len(chembl_ids)
# Out:
# 962

# %%
import time
import csv

# Collect all ChEMBL-UniProt mappings
chembl_uniprot_map = []
unique_uniprots = set()

for chembl_id in chembl_ids:
    uniprot_ids = get_uniprot_ids(chembl_id)

    # Ensure it's a list (in case function returns a single string)
    if isinstance(uniprot_ids, str):
        uniprot_ids = [uniprot_ids]

    # Keep only new (unique) UniProt IDs
    new_uniprots = [uid for uid in uniprot_ids if uid not in unique_uniprots]

    # Add to mapping and mark as seen
    for uid in new_uniprots:
        chembl_uniprot_map.append((chembl_id, uid))
        unique_uniprots.add(uid)

    time.sleep(0.1)  # be nice to the API

# Save to CSV
with open("multitask_chembl_uniprot.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["chembl_id", "uniprot_id"])
    writer.writerows(chembl_uniprot_map)

# %%
# Collect all UniProt IDs
all_uniprot_ids = ()
for chembl_id in chembl_ids:
    uniprot_ids = get_uniprot_ids(chembl_id)

    if len(uniprot_ids) == 1:
        all_uniprot_ids.extend((chembl_id, uniprot_ids))
    else:
        for uniprot_id in uniprot_ids:
            all_uniprot_ids.extend((chembl_id, uniprot_id))
    time.sleep(0.1)  # Be nice to the API

# Remove duplicates and write to output file
unique_uniprot_ids = list(set(all_uniprot_ids))
with open('uniprot_ids_multitask.txt', 'w') as f:
    for uniprot_id in unique_uniprot_ids:
        f.write(f"{uniprot_id}\n")

print(f"Processed {len(chembl_ids)} ChEMBL IDs")
print(f"Found {len(unique_uniprot_ids)} unique UniProt IDs")
print("Output written to uniprot_ids_ppb.txt")
# Out:
# Processed 962 ChEMBL IDs
# Found 4748 unique UniProt IDs
# Output written to uniprot_ids_ppb.txt

# %%
# Read ChEMBL IDs from input file
with open('xfp_chembls.txt', 'r') as f:
    chembl_ids = [line.strip() for line in f if line.strip()]

# %%
uniprot_ids = [get_uniprot_ids(id) for id in chembl_ids]

# %%
uniprot_ids
# Out:
# [['P11511', 'Q16731', 'Q3B764', 'Q58FA0', 'Q8IYJ7'],
#  ['O95569', 'P18054', 'Q6ISF8', 'Q9UQM4'],
#  ['A8K2P4', 'B7ZA11', 'P16050', 'Q8N6R7', 'Q99657'],
#  ['B2R6R3', 'B7Z5H3', 'D3DWC3', 'P27338', 'Q7Z6S2'],
#  ['P37136'],
#  ['A8K8K5',
#   'G3V5M5',
#   'O60608',
#   'O60685',
#   'O60702',
#   'O60703',
#   'O75583',
#   'O75584',
#   'Q0MWT5',
#   'Q0MWT6',
#   'Q86Z31',
#   'Q92731',
#   'Q9UEV6',
#   'Q9UHD3',
#   'Q9UQK9'],
#  ['Q13511',
#   'Q14276',
#   'Q5T5H7',
#   'Q6MZQ9',
#   'Q9NU51',
#   'Q9UDZ7',
#   'Q9UIS7',
#   'P03372'],
#  ['P42345', 'Q4LE76', 'Q5TER1', 'Q6LE87', 'Q96QG3', 'Q9Y4I3'],
#  ['A5Z1R8', 'B2R4S3', 'Q2V4Y5', 'Q6FHV0', 'P14174'],
#  ['B2RA44', 'P21728', 'Q4QRJ0'],
#  ['B4DF46', 'P21397', 'Q16426'],
#  ['B2R7G8', 'Q6FI12', 'Q96ET9', 'P00918'],
#  ['A4D0Q6', 'Q8IV23', 'Q9BZC8', 'P48736'],
#  ['P06211'],
#  ['P25099'],
#  ['P18901', 'P21669'],
#  ['D3DNF0', 'P42338', 'Q24JU2'],
#  ['Q14CW1', 'Q99762', 'P42336'],
#  ['P78527',
#   'P78528',
#   'Q13327',
#   'Q13337',
#   'Q14175',
#   'Q59H99',
#   'Q7Z611',
#   'Q96SE6',
#   'Q9UME3'],
#  ['P14416', 'Q9NZR3', 'Q9UPA9'],
#  ['B3KV35', 'Q8TDU6'],
#  ['A1L4K5',
#   'B7Z412',
#   'B7ZM06',
#   'F8VYG8',
#   'Q8NFP5',
#   'Q8NFP6',
#   'Q92943',
#   'Q96RI1'],
#  ['B9EGB6', 'Q14973', 'Q2TU29'],
#  ['P30304', 'Q8IZH5', 'Q96IL3', 'Q9H2F2'],
#  ['A1L4F4', 'Q12908', 'Q13839'],
#  ['A4D2J7', 'B7ZLE6', 'D3DVK9', 'Q17RV5', 'Q6R3Q4', 'Q9UHC8', 'Q9UHC9'],
#  ['B2RE87', 'P31213', 'Q2M1R4', 'Q9BYE6'],
#  ['Q5TGD8', 'Q9BQV9', 'Q9NQQ4', 'P18031'],
#  ['A8K3J9', 'D3DQR1', 'Q13133', 'Q8IW13', 'Q96H87'],
#  ['B2R7Q1', 'P18405', 'Q9UHY4', 'Q9UP36', 'Q9UP37'],
#  ['D3DWX9',
#   'P11413',
#   'Q16000',
#   'Q16765',
#   'Q8IU70',
#   'Q8IU88',
#   'Q8IUA6',
#   'Q96PQ2'],
#  ['D3DVY1',
#   'D3DVY2',
#   'D3DVY3',
#   'D3DVY4',
#   'O43551',
#   'P30305',
#   'Q13971',
#   'Q5JX77',
#   'Q6RSS1',
#   'Q9BRA6'],
#  ['Q5SZR9', 'Q8N5V7', 'Q8NCY8', 'P51449'],
#  ['A0ZXF9',
#   'B0LPG8',
#   'D3DQF4',
#   'F5ATB7',
#   'P04150',
#   'P04151',
#   'Q53EP5',
#   'Q6N0A4'],
#  ['P06766', 'Q4G081'],
#  ['P05093', 'Q5TZV7'],
#  ['A4D1P1', 'O60218', 'O75890', 'Q6FHF3', 'Q8IWZ1'],
#  ['E7EMT8', 'Q5JAR4', 'Q9NPD5'],
#  ['B2R7G2', 'Q29R64', 'Q9NQ37', 'Q9UBF3', 'Q9UH89', 'Q9Y6L6'],
#  ['B0FWH4',
#   'B4DYU0',
#   'E9PGW1',
#   'F5H5Z8',
#   'I3L1N7',
#   'P04278',
#   'P14689',
#   'Q16616',
#   'Q3MIL0',
#   'Q6ISD2'],
#  ['P00915'],
#  ['P54707', 'Q13816', 'Q13817', 'Q16734', 'Q5W035', 'Q8N5U2'],
#  ['P12527'],
#  ['B3KRS5', 'B4DL58', 'E1P561', 'Q5SRI8', 'Q5SZ86', 'Q8NEH4', 'Q92769'],
#  ['B7ZLS0', 'E5FPY5', 'E5FPY7', 'E5FPY8', 'P09917', 'Q5JQ14'],
#  ['Q6GTV1', 'Q6SLK1', 'Q04206'],
#  ['A6ND12',
#   'A6ND61',
#   'A6NET3',
#   'A6NJR3',
#   'A8MQ62',
#   'B4DKN0',
#   'B4DV22',
#   'Q86VC8',
#   'Q9BY41',
#   'Q9NP76',
#   'Q9NYH4'],
#  ['B2R5V1',
#   'B4DII8',
#   'D3DSD1',
#   'D3DSD2',
#   'D3DSD3',
#   'P09000',
#   'P78438',
#   'Q13764',
#   'Q13778',
#   'Q13793',
#   'Q16011',
#   'Q16014',
#   'Q16019',
#   'Q16020',
#   'Q6GSC0',
#   'Q8WZ99',
#   'Q9BT38',
#   'Q9UC33',
#   'Q9UCA9',
#   'Q9UCB6',
#   'Q9UCC8',
#   'Q9UCD1',
#   'Q9UQ58',
#   'P05067'],
#  ['B3KVL9', 'B7Z1T9', 'B7Z1U6', 'F5GXM5', 'Q14833', 'Q5SZ84', 'Q6ZMQ2'],
#  ['Q9H4B7'],
#  ['P15538', 'Q14095', 'Q4VAQ8', 'Q4VAQ9', 'Q9UML2'],
#  ['A8K802', 'P35354', 'Q16876'],
#  ['B1B5Y2', 'P08069', 'Q14CV2', 'Q9UCC0'],
#  ['P13953', 'P61169'],
#  ['A8K2A4', 'Q13701', 'Q4JHI3', 'Q6IAU6', 'P37840'],
#  ['B0ZBE4', 'P19099', 'Q16726'],
#  ['D3DQ19', 'O00519', 'Q52M86', 'Q5TDF8'],
#  ['Q8N632', 'Q96GK1', 'Q9HD92', 'Q9NY70', 'Q9NYA1', 'Q9NYL3'],
#  ['P97612', 'Q5BKA3'],
#  ['B2R9T4',
#   'E1P512',
#   'P21554',
#   'Q13949',
#   'Q495Z0',
#   'Q4PLI4',
#   'Q4VBM6',
#   'Q5JVL5',
#   'Q5UB37',
#   'Q9UNN0'],
#  ['C6ES44', 'P34972', 'Q4VBK8', 'Q5JRH7', 'Q6B0G7', 'Q6NSY0'],
#  ['P20272'],
#  ['B5BU22', 'P17252', 'Q15137', 'Q32M72', 'Q96RE4'],
#  ['A2RUN4', 'Q01959', 'Q14996'],
#  ['B2R707', 'B4DX48', 'P23975', 'Q96KH8'],
#  ['P31645', 'Q5EE02'],
#  ['A2RUA9',
#   'Q3LU47',
#   'Q8NER1',
#   'Q9H0G9',
#   'Q9H303',
#   'Q9H304',
#   'Q9NQ74',
#   'Q9NY22'],
#  ['B2Z3B1',
#   'B3KTU8',
#   'B3KUA0',
#   'G3V134',
#   'J3KPH7',
#   'Q16764',
#   'Q9HBJ1',
#   'Q9HBJ2',
#   'P34913'],
#  ['A0T4C8', 'B4DU87', 'Q9BRN1', 'Q9H0Q2', 'Q9NRA0', 'Q9NWU7'],
#  ['P33535',
#   'Q2TV20',
#   'Q2TV21',
#   'Q4VWM5',
#   'Q4VWM7',
#   'Q4VWX7',
#   'Q4VWX8',
#   'Q62846',
#   'Q64064',
#   'Q64120'],
#  ['B4DJZ9', 'D3DSN0', 'E9PEI9', 'G5E9Q9', 'P48449', 'Q8IYL6', 'Q9UEZ1'],
#  ['P48450', 'Q62811'],
#  ['A6NIM1',
#   'A8K3K8',
#   'A8K844',
#   'E9PAU8',
#   'P23141',
#   'P82127',
#   'Q00015',
#   'Q13657',
#   'Q14062',
#   'Q16737',
#   'Q16788',
#   'Q549X7',
#   'Q549X8',
#   'Q86UK2',
#   'Q96EE8',
#   'Q9UC52',
#   'Q9UDG8',
#   'Q9UK77',
#   'Q9ULY2'],
#  ['B1AMW4', 'P28335', 'Q5VUF8', 'Q9NP28'],
#  ['B1ANJ4', 'Q8IUZ9', 'P09874'],
#  ['B4DQA4', 'P22748', 'Q6FHI7'],
#  ['P08908', 'Q6LAE7'],
#  ['Q16790', 'Q5T4R1'],
#  ['P19327'],
#  ['P28222', 'Q4VAY7'],
#  ['E7EMQ1', 'P23280', 'Q5FBW3', 'Q5FC00', 'Q96QX8', 'Q9UF03'],
#  ['P28221'],
#  ['P28564'],
#  ['P08909'],
#  ['B2RPF2', 'P35218'],
#  ['E5RGR8', 'F6M9T7', 'P14902', 'Q540B4'],
#  ['P43166', 'Q541F0', 'Q86YU0'],
#  ['B2RAC5', 'B4DZ79', 'F5GWE8', 'P28223', 'Q5T8C0'],
#  ['P23976', 'P31652'],
#  ['Q5TB24', 'Q8NCF4', 'Q9ULX7'],
#  ['P50406', 'Q13640', 'Q5TGZ1'],
#  ['Q15391', 'Q8IYT7'],
#  ['B2R9W3', 'P41231', 'Q96EM8'],
#  ['P51582', 'Q4VBB7', 'Q4VBB8', 'Q502W2', 'Q5JT22'],
#  ['Q15077', 'Q15754'],
#  ['B2LUJ9', 'O43598'],
#  ['O35820'],
#  ['P47900'],
#  ['B2RE24', 'O43570', 'Q53YE5', 'Q9BWG2'],
#  ['P12268', 'Q6LEF3'],
#  ['P29994', 'Q62869'],
#  ['A6NFY5',
#   'A6NGP4',
#   'A8K1L3',
#   'B3KXQ4',
#   'D2CGD0',
#   'P30542',
#   'Q6FHK3',
#   'Q8TAM8'],
#  ['Q5SQD8', 'Q7Z5I2', 'Q99500'],
#  ['A4D0Z6',
#   'A4D0Z7',
#   'A6NDW5',
#   'A6NNI6',
#   'B3KNP7',
#   'B3KVM8',
#   'B4DE09',
#   'C9JV30',
#   'J3KNX8',
#   'P20839',
#   'Q8N194',
#   'Q96NU2'],
#  ['D3DT66', 'P21453', 'Q9BYY4', 'Q9NYN8'],
#  ['A6NHF0', 'B2R8M9', 'P00492'],
#  ['Q6NW11', 'Q9H228'],
#  ['A2A3P4', 'P0DMS8', 'P33765', 'Q6UWU0', 'Q9BYZ1'],
#  ['P23739'],
#  ['P27487', 'Q53TN1'],
#  ['P18090'],
#  ['A8K796',
#   'B7Z5G2',
#   'B7Z6S1',
#   'J3KQG4',
#   'J3KQK9',
#   'P04062',
#   'Q16545',
#   'Q4VX22',
#   'Q6I9R6',
#   'Q9UMJ8'],
#  ['Q6P7A9'],
#  ['B2R810', 'P16662', 'Q6GTW0'],
#  ['P11229', 'Q96RH1'],
#  ['B7WPB9',
#   'D3DR79',
#   'E9PGF9',
#   'O60502',
#   'O75166',
#   'Q86WV0',
#   'Q8IV98',
#   'Q9BVA5',
#   'Q9HAR0'],
#  ['P10980', 'Q9Z2Z1'],
#  ['P43681', 'Q4JGR7', 'Q4VAQ5', 'Q4VAQ6'],
#  ['B2R9D5', 'P41595', 'Q53TI1', 'Q62221', 'Q6P523'],
#  ['P08172', 'Q4VBK6', 'Q9P1X9'],
#  ['P20309', 'Q0VAJ8', 'Q4QRI3', 'Q5VXY2', 'Q9HB60'],
#  ['A8K3G6',
#   'B5BUA1',
#   'O00684',
#   'O00710',
#   'O14515',
#   'Q0QJH8',
#   'Q15178',
#   'Q15179',
#   'Q15180',
#   'Q15832',
#   'Q86U60',
#   'Q96J12',
#   'P37231'],
#  ['B0G0X3', 'Q16241', 'Q6I9S0', 'Q92486', 'Q92689', 'Q9Y3N1', 'Q07869'],
#  ['A8K6J6',
#   'B4E3V3',
#   'B6ZGS1',
#   'B7Z3W1',
#   'E9PE18',
#   'Q03181',
#   'Q5D1P0',
#   'Q7Z5K0',
#   'Q9BUD4'],
#  ['B4DJG6',
#   'E7EMU9',
#   'E7EP08',
#   'E7ESB5',
#   'O14987',
#   'P24557',
#   'Q16843',
#   'Q16844',
#   'Q8IUN1',
#   'Q96CN2',
#   'Q9GZW4',
#   'Q9HD77',
#   'Q9HD78',
#   'Q9HD79',
#   'Q9HD80',
#   'Q9HD81',
#   'Q9HD82',
#   'Q9HD83',
#   'Q9HD84'],
#  ['O75228', 'P21731', 'Q6DK52', 'Q9UCY1', 'Q9UCY2'],
#  ['A0AVA3', 'Q9UBY5'],
#  ['Q86WP7', 'Q8NGW4', 'Q8TDS5'],
#  ['O00543', 'O43431', 'Q9HBW0'],
#  ['B7Z3Y9', 'P04035', 'Q8N190'],
#  ['B4DK36', 'O00656', 'O00722', 'P78351', 'Q92633'],
#  ['A8UHA1',
#   'E9PHP7',
#   'Q13822',
#   'Q13827',
#   'Q14555',
#   'Q15117',
#   'Q9UCQ8',
#   'Q9UCR0',
#   'Q9UCR1',
#   'Q9UCR2',
#   'Q9UCR3',
#   'Q9UCR4'],
#  ['P37058', 'Q5U0Q6'],
#  ['P07943'],
#  ['B7WPG1',
#   'G3XAN7',
#   'Q19PF7',
#   'Q19PF8',
#   'Q19PF9',
#   'Q19PG0',
#   'Q6UXW3',
#   'Q96DT2',
#   'Q96S37'],
#  ['B2R8N3', 'Q5U031', 'Q6FGA4', 'Q6ICP2', 'Q9BS21', 'Q9UCI9', 'P15121'],
#  ['Q8N580', 'Q9Y2T6'],
#  ['B2R5P0', 'P08238', 'Q5T9W7', 'Q9NQW0', 'Q9NTK6'],
#  ['B5B0B8', 'P41143'],
#  ['B0FXJ1',
#   'B2R9S7',
#   'B8Q1L7',
#   'B8Q1L8',
#   'B8Q1L9',
#   'E7EWZ3',
#   'G8XRH6',
#   'G8XRH8',
#   'P35372',
#   'Q12930',
#   'Q4VWM1',
#   'Q4VWM2',
#   'Q4VWM3',
#   'Q4VWM4',
#   'Q4VWM6',
#   'Q4VWX6',
#   'Q5TDA1',
#   'Q6UPP1',
#   'Q6UQ80',
#   'Q7Z2D8',
#   'Q86V80',
#   'Q8IWW3',
#   'Q8IWW4',
#   'Q9UCZ4',
#   'Q9UN57'],
#  ['E5RHC9', 'P41145', 'Q499G4'],
#  ['A2RRS0', 'B5A925', 'C5IFA0', 'O60723', 'Q14178', 'P35968'],
#  ['Q38RT9', 'Q5T7H7', 'Q96RG3', 'P11309'],
#  ['O14842', 'Q0VAS2', 'Q4VBL4'],
#  ['A8K4T5', 'Q9Y2D0'],
#  ['O94975', 'Q6NT75', 'Q7L3E5', 'Q96CY0', 'Q9UBN7'],
#  ['Q2M1W5', 'Q3MIH8', 'Q5VUQ1', 'Q96RJ0'],
#  ['P21396', 'Q63817'],
#  ['B2R8L7', 'D3DQZ1', 'O75936', 'Q6IBJ2'],
#  ['B2R9Z1', 'D3DT89', 'P28845'],
#  ['A0PJL5', 'A7LGG3', 'Q8TDS4'],
#  ['Q07075', 'Q504U2'],
#  ['P15144', 'Q16728', 'Q6GT90', 'Q8IUK3', 'Q8IVH3', 'Q9UCE0'],
#  ['A4D2E2',
#   'B7ZKZ0',
#   'D6W5X7',
#   'P22303',
#   'Q16169',
#   'Q29S23',
#   'Q2M324',
#   'Q504V3',
#   'Q53F46',
#   'Q86TM9',
#   'Q86YX9',
#   'Q9BXP7'],
#  ['A4UU12',
#   'A9CB79',
#   'B7Z312',
#   'B7Z343',
#   'D3DQS5',
#   'E9PDX8',
#   'O43748',
#   'Q04609',
#   'Q16305',
#   'Q541A4',
#   'Q8TAY3',
#   'Q9NP15',
#   'Q9NYE2',
#   'Q9P1P8'],
#  ['A8K1V7',
#   'B4DHQ2',
#   'B4E2S5',
#   'P23219',
#   'Q15122',
#   'Q3HY28',
#   'Q3HY29',
#   'Q5T7T6',
#   'Q5T7T7',
#   'Q5T7T8'],
#  ['P41594', 'Q6J164'],
#  ['P31424'],
#  ['B2RPP4', 'P08173', 'Q0VD60', 'Q4VBK7'],
#  ['Q05941', 'Q53YK2'],
#  ['B2R6U1', 'B4DWH3', 'E9PE45', 'P08253', 'Q9UCJ8'],
#  ['P23977'],
#  ['A8K7Q4',
#   'B4DFS0',
#   'P36544',
#   'Q15826',
#   'Q8IUZ4',
#   'Q96RH2',
#   'Q99555',
#   'Q9BXH0'],
#  ['A0A024R6X1',
#   'A8K367',
#   'O00748',
#   'Q16859',
#   'Q5MAB8',
#   'Q7Z366',
#   'Q8IUP4',
#   'Q8TCP8'],
#  ['A8K7U7', 'Q5VSF1', 'Q969X4', 'Q9UHL4'],
#  ['A1L401', 'B4DJK8', 'B4DQT5', 'B7ZBQ7', 'P24046', 'Q9BX06'],
#  ['B2RAB6', 'P05413', 'Q5VV93', 'Q99957'],
#  ['P19643', 'Q5EBB5'],
#  ['P49286'],
#  ['A0AVC5', 'B0M0L2', 'P48039'],
#  ['B3KU79', 'P10828', 'P37243', 'Q13986', 'Q3KP35', 'Q6WGL2', 'Q9UD41'],
#  ['A8K3B5', 'P10827', 'P21205', 'Q8N6A1', 'Q96H73'],
#  ['O94765', 'Q4QRI6', 'Q9Y5Y4'],
#  ['D3DN89', 'Q9BWH3', 'Q9UL47', 'P49841'],
#  ['A8K4G5', 'B2R830', 'E9PI97', 'P49019', 'Q8NGE4'],
#  ['B2R7I5', 'P14920', 'Q16758', 'Q8N6R2'],
#  ['O70196'],
#  ['B2R867', 'B3KUC8', 'O60842', 'P07451'],
#  ['Q02769'],
#  ['A0AVM1', 'P31941', 'Q12807', 'Q5JZ93', 'Q9UH18'],
#  ['Q6IBA1', 'P15090'],
#  ['A8K955', 'A8MXU3', 'K7ENG3', 'P17706', 'Q96AU5', 'Q96HR2'],
#  ['O14684', 'O14900', 'Q5SZC0'],
#  ['A8K294', 'B5AK60', 'P08183', 'Q12755', 'Q14812'],
#  ['A7LB28',
#   'C5HTY7',
#   'P80365',
#   'Q13194',
#   'Q6P2G9',
#   'Q8N439',
#   'Q96QN8',
#   'Q99887',
#   'Q9UC50',
#   'Q9UC51',
#   'Q9UCW5',
#   'Q9UCW6',
#   'Q9UCW7',
#   'Q9UCW8'],
#  ['O70536'],
#  ['A8K7P8', 'P06276'],
#  ['B2R4H5', 'P04054', 'Q3KPI1'],
#  ['P13053'],
#  ['A8MW15', 'H9KVA0', 'P19971', 'Q13390', 'Q8WVB7'],
#  ['P29275'],
#  ['Q9HAZ1'],
#  ['B2R7E0', 'P29274'],
#  ['A8K4G6', 'Q99739', 'Q9P1W9'],
#  ['Q6P7S1', 'Q9EQJ6'],
#  ['A5D8X8', 'A8K7J0', 'B1B0P0', 'Q68BM2', 'Q86V86'],
#  ['B2RDR9', 'Q45F02', 'Q5TF77', 'Q7Z2N1', 'Q7Z2N4', 'Q9H9H8', 'Q9HC16'],
#  ['A8K3E3', 'P07327', 'Q17R68'],
#  ['A0S0A7',
#   'A0S0A8',
#   'A8KA63',
#   'B2RCQ1',
#   'E9PFR2',
#   'P29474',
#   'Q13662',
#   'Q14251',
#   'Q14434',
#   'Q548C1',
#   'Q6GSL5',
#   'Q9UDC6'],
#  ['P08483', 'Q9QWK9'],
#  ['A1L3U5',
#   'B7ZLY2',
#   'O60757',
#   'O94994',
#   'P35228',
#   'Q16263',
#   'Q16692',
#   'Q4TTS5',
#   'Q9UD42'],
#  ['O35769', 'P09483'],
#  ['A1L4B8', 'P05164', 'Q14862', 'Q4PJH5', 'Q9UCL7'],
#  ['Q9WTR4'],
#  ['P14842'],
#  ['P30994', 'Q9QW44'],
#  ['B5BUP6',
#   'P34969',
#   'P78336',
#   'P78372',
#   'P78516',
#   'Q5VX01',
#   'Q5VX02',
#   'Q5VX03'],
#  ['A7YAE5',
#   'B2R7F6',
#   'P00190',
#   'P10890',
#   'P11509',
#   'Q16803',
#   'Q4VAT9',
#   'Q4VAU0',
#   'Q4VAU1',
#   'Q9H1Z7',
#   'Q9UCU0',
#   'Q9UK48'],
#  ['B2R7T4', 'P37059'],
#  ['P33533'],
#  ['B3KXS1', 'P14061', 'Q2M2L8'],
#  ['D3DRM7',
#   'O00673',
#   'O00725',
#   'Q0Z9W6',
#   'Q153Z1',
#   'Q2TSD1',
#   'Q53GN2',
#   'Q7Z653',
#   'Q8N7H3',
#   'Q99720',
#   'Q9NYX0'],
#  ['B2R7V9',
#   'P14780',
#   'Q3LR70',
#   'Q8N725',
#   'Q9H4Z1',
#   'Q9UCJ9',
#   'Q9UCL1',
#   'Q9UDK2'],
#  ['P03956', 'P08156'],
#  ['P05184', 'Q16757', 'Q9UK50', 'P08684'],
#  ['Q9R0C9', 'Q9R1J7', 'Q9Z2W2'],
#  ['A8K7B8', 'K7ENL3', 'O14916', 'P40763', 'Q9BW54'],
#  ['P14679', 'Q15675', 'Q15676', 'Q15680', 'Q8TAK4', 'Q9BYY0', 'Q9BZX1'],
#  ['A8K500', 'B3KPJ9', 'Q2PP14', 'Q5CAQ6', 'Q5CAQ7', 'Q9BVQ5', 'P07900'],
#  ['P01585', 'P60568'],
#  ['A2RUC3', 'P14410', 'Q1JQ80', 'Q1RMC2'],
#  ['A0AV69',
#   'A8K2C4',
#   'O75026',
#   'O75887',
#   'O76074',
#   'Q86UI0',
#   'Q86V66',
#   'Q9Y6Z6'],
#  ['E7ER45', 'O43451', 'Q0VAX6', 'Q75ME7', 'Q86UM5'],
#  ['P53792'],
#  [],
#  ['B2R8S5', 'D3DS00', 'P00491', 'Q15160', 'Q5PZ03'],
#  ['P47989', 'Q16681', 'Q16712', 'Q4PJ16'],
#  ['A8K934', 'B4DDD0', 'B4DSK3', 'B5BTY6', 'F5H7S4', 'H2BI51', 'O14757'],
#  ['P30543'],
#  ['O60769', 'Q13627', 'Q92582', 'Q92810', 'Q9UNM5'],
#  ['Q80Z39'],
#  ['D6W587', 'O94806', 'Q53TR7', 'Q8NEL8'],
#  ['A1XKG3', 'Q00535'],
#  ['E1P5F9', 'O60445', 'O75873', 'Q9BQD6', 'Q9UPG5', 'O14965'],
#  ['B2R9V4', 'P51812', 'Q4VAP3', 'Q59H26', 'Q5JPK8', 'Q7Z3Z7'],
#  ['P39086', 'Q13001', 'Q86SU9'],
#  ['P22756'],
#  ['O08620', 'O08621', 'Q9Z0F9', 'Q9Z0U4', 'Q9Z308'],
#  ['A6NMY9',
#   'B5MCV0',
#   'D7RWZ3',
#   'D7RWZ4',
#   'D7RWZ5',
#   'D7RWZ6',
#   'D7RWZ7',
#   'Q13002',
#   'Q8WWS1',
#   'Q96KS6',
#   'Q96KS7',
#   'Q96KS8'],
#  ['A8K464', 'Q15114', 'Q5T9K1', 'Q5T9K2', 'Q96IY4', 'Q9P2Y6'],
#  ['O35420', 'P42264'],
#  ['Q93088', 'Q9UNI9'],
#  ['P70594', 'P29476'],
#  ['B2R7E2', 'B7Z4Q9', 'B7ZA69', 'P13866'],
#  ['Q6AY53'],
#  ['Q6V1X1',
#   'Q7Z4C8',
#   'Q7Z4D3',
#   'Q7Z4E1',
#   'Q8IWG7',
#   'Q8NEM5',
#   'Q96JX1',
#   'Q9HBM2',
#   'Q9HBM3',
#   'Q9HBM4',
#   'Q9HBM5',
#   'Q9NXF4'],
#  ['E9PH30', 'O75713', 'P29475'],
#  ['B0YJ19', 'B2KJ48', 'Q4G0I6', 'Q9GZQ0', 'Q9H3N8'],
#  ['B2R5Q1', 'G3V1V9', 'P11473', 'Q5PSV3'],
#  ['A0A0B4J1T2',
#   'A2RUN2',
#   'B1AKD7',
#   'C0JKD3',
#   'C0JKD4',
#   'E7EVX6',
#   'Q9UD95',
#   'P10275'],
#  ['B5A968', 'Q8N3Z2', 'P29317'],
#  ['B2R6B2',
#   'D3DV03',
#   'D3DV04',
#   'Q9HD91',
#   'Q9NRQ3',
#   'Q9NRQ4',
#   'Q9UHR7',
#   'Q9UHR8',
#   'Q9UHR9',
#   'Q9UNJ1',
#   'Q07820'],
#  ['B2R6P7',
#   'B4DDV0',
#   'P78375',
#   'Q04760',
#   'Q59EL0',
#   'Q5TZW3',
#   'Q96FC0',
#   'Q96J41'],
#  ['O00460', 'P09211', 'Q15690', 'Q5TZY3'],
#  ['B4DTU3', 'Q549U4', 'Q8IWF5', 'Q9Y239'],
#  ['B0LPF0',
#   'B4DXI3',
#   'E7EU16',
#   'P22966',
#   'Q53YX9',
#   'Q59GY8',
#   'Q7M4L4',
#   'P12821'],
#  ['A8K6U6', 'D3DNJ9', 'P08473', 'Q3MIX4'],
#  ['P19490'],
#  ['B4DNQ9', 'F8VV40', 'P09960', 'Q6IAT6', 'Q9UCT7'],
#  ['A8K1A5', 'B4E2A7', 'Q16348'],
#  ['B7Z2S0',
#   'B7Z2W8',
#   'B7Z3F6',
#   'B7Z9G9',
#   'D3DQI4',
#   'E7ESV8',
#   'P42261',
#   'Q2NKM6'],
#  ['A8K3P1',
#   'B4E291',
#   'P42892',
#   'Q14217',
#   'Q17RN5',
#   'Q2Z2K8',
#   'Q58GE7',
#   'Q5THM5',
#   'Q5THM7',
#   'Q5THM8',
#   'Q9UJQ6',
#   'Q9UPF4',
#   'Q9UPM4',
#   'Q9Y501'],
#  ['P07861'],
#  ['Q14340', 'P00742'],
#  ['A6NIN6', 'O75762'],
#  [],
#  ['P31423'],
#  ['P70579'],
#  ['P35349'],
#  ['B0M0K7', 'Q14416', 'Q14CU5', 'Q52MC6', 'Q9H3N6'],
#  ['O15303'],
#  ['A8MT92', 'I6L997', 'P42262', 'Q96FP6'],
#  ['A4D0Y3',
#   'B0FZ74',
#   'B0M0L0',
#   'O00222',
#   'O15493',
#   'O95945',
#   'O95946',
#   'Q3MIV9',
#   'Q52M02',
#   'Q6J165'],
#  ['Q9R174', 'P19491'],
#  ['P31421'],
#  ['O00688',
#   'O00732',
#   'P06268',
#   'Q14225',
#   'Q68GS5',
#   'Q92795',
#   'Q9BZS2',
#   'Q9GZX1',
#   'Q9H2C9',
#   'Q9H3C9',
#   'Q9UMD7',
#   'Q9UMD8',
#   'Q9UMG5',
#   'P00533'],
#  ['E1P5V4', 'Q76P87', 'Q86VB9', 'Q9H5A8', 'P12931'],
#  ['Q15761', 'Q6GTR7', 'Q92916'],
#  ['A7LQ08', 'A7X8B0', 'B4E3T0', 'P06401', 'Q8TDS3', 'Q9UPF7'],
#  ['D3DPP8',
#   'P07100',
#   'Q12850',
#   'Q13152',
#   'Q5TDH8',
#   'Q5TDH9',
#   'Q7RTZ3',
#   'Q96DW4',
#   'Q9NYT8',
#   'P06239'],
#  ['A6ZJ92',
#   'A8K6P4',
#   'B0LPH0',
#   'B5TY32',
#   'O60776',
#   'Q13083',
#   'Q14084',
#   'Q8TDX0',
#   'Q16539'],
#  ['A5H1P7',
#   'C4PFH9',
#   'D3DX04',
#   'O75418',
#   'O75680',
#   'Q12809',
#   'Q708S9',
#   'Q9BT72',
#   'Q9BUT7',
#   'Q9H3P0'],
#  ['A8K6T9',
#   'A8K8V5',
#   'C1KBH8',
#   'P17049',
#   'Q02063',
#   'Q02065',
#   'Q14306',
#   'Q14307',
#   'Q53H63',
#   'Q59H40',
#   'Q5BJG2',
#   'Q8N685',
#   'Q9UD50',
#   'Q9UDF0',
#   'Q9UDF1',
#   'Q9UDF2',
#   'P11362'],
#  ['E7ESS2', 'O75172', 'O95819', 'Q9NST7'],
#  ['P10635', 'Q16752', 'Q2XND6', 'Q2XND7', 'Q2XNE0', 'Q6B012', 'Q6NXU8'],
#  ['A3KFJ3', 'Q13869', 'Q13870', 'Q16133', 'Q17R61', 'Q45F09', 'P00519'],
#  ['B7Z6I8',
#   'D3DXF4',
#   'D3DXF5',
#   'O15283',
#   'P53667',
#   'Q15820',
#   'Q15821',
#   'Q75MU3',
#   'Q9Y5Q1'],
#  ['A8K715',
#   'B7Z520',
#   'E7EMD7',
#   'Q5K3R4',
#   'Q5K3R5',
#   'Q5K3R6',
#   'Q5K3R8',
#   'Q7Z7G3',
#   'Q86V92',
#   'Q9NPH5'],
#  ['Q16678', 'Q5TZW8', 'Q93089', 'Q9H316'],
#  ['A4F3V9', 'A4F3W0', 'P04798', 'Q53G18'],
#  ['B2R7Y4', 'P09923', 'Q53S80', 'Q9UBV5', 'Q9UCL2'],
#  ['A0A1W3',
#   'A8K1T5',
#   'O95374',
#   'Q4W5I3',
#   'Q53ZQ1',
#   'Q569L4',
#   'Q5YLG4',
#   'Q86V64',
#   'Q8IX16',
#   'Q96LD6',
#   'Q96TA8',
#   'Q9BY73',
#   'Q9NUS0',
#   'Q9UNQ0'],
#  ['O14746', 'O14783', 'Q2XS35', 'Q8N6C3', 'Q8NG38', 'Q8NG46'],
#  ['A3RJX2',
#   'C9JPJ4',
#   'O14819',
#   'O43333',
#   'P33527',
#   'P78419',
#   'Q59GI9',
#   'Q9UQ97',
#   'Q9UQ99',
#   'Q9UQA0'],
#  ['P05177', 'Q16754', 'Q6NWU3', 'Q6NWU5', 'Q9BXX7', 'Q9UK49'],
#  ['A8K2V0',
#   'B4DL37',
#   'P42330',
#   'Q5T2L1',
#   'Q96DJ1',
#   'Q96KI8',
#   'Q99530',
#   'Q9UCX1',
#   'Q9UII3',
#   'Q9UKL9'],
#  ['D3DRP2', 'Q5TCV6', 'Q96A51', 'Q96LY1', 'Q96SJ2', 'Q9H2L8', 'Q9HCG7'],
#  ['P10253', 'Q09GN4', 'Q14351', 'Q16302', 'Q8IWE7'],
#  ['B2RBG3', 'P04066', 'Q14334', 'Q14335', 'Q3LID0', 'Q8NAC2'],
#  ['Q16739', 'Q5T258'],
#  ['A2RRD2', 'P31639'],
#  ['P32320'],
#  ['P08482'],
#  ['B2RC58', 'P04183', 'Q969V0', 'Q9UMG9'],
#  ['A8K307', 'B3KUN3', 'E1P5P2', 'F5H737', 'P23526', 'Q96A36'],
#  ['P28647', 'Q63792'],
#  ['P00813', 'Q53F92', 'Q6LA59'],
#  ['Q04400'],
#  ['Q6Y1R5'],
#  ['B7Z783',
#   'B7Z800',
#   'O00741',
#   'O00742',
#   'P55263',
#   'Q16710',
#   'Q5JQ10',
#   'Q5JQ11',
#   'Q9BTN2'],
#  ['E1P5F7', 'P17707', 'Q5VXN4', 'Q5VXN6', 'Q9BWK4'],
#  ['O09162', 'Q642G1', 'Q64640'],
#  ['O60379', 'Q8TEK3', 'Q96JL1'],
#  ['B3KQV7', 'B3KQY5', 'Q5T9W9', 'Q99808', 'Q9UJY2'],
#  ['P17612', 'Q32P54', 'Q9H2Y0', 'Q9NRB4', 'Q9NRH9'],
#  ['O14636', 'O75297', 'O60674'],
#  ['P16455', 'Q5VY78'],
#  ['B4DYS6', 'D3DVV8', 'P19138', 'P20426', 'Q14013', 'Q5U065', 'P68400'],
#  ['D3DT31', 'O00311', 'O00558', 'Q5T5U5'],
#  ['B4DDD2', 'P00374', 'Q14130', 'Q6IRW8'],
#  ['Q920D2'],
#  ['P04818', 'Q8WYK3', 'Q8WYK4'],
#  ['Q13547', 'Q92534'],
#  ['A8K945', 'A8KA32', 'D3DSF3', 'D3DSF4', 'O14659', 'P22102', 'Q52M77'],
#  ['B3KPW4', 'B7Z2Z3', 'F5H0K6', 'Q05932', 'Q5JU19', 'Q5JU22', 'Q6P2P6'],
#  ['B2R7U8',
#   'B7Z8C3',
#   'E9PFY4',
#   'O00553',
#   'O60227',
#   'P41440',
#   'Q13026',
#   'Q9BTX8'],
#  ['A8K202', 'E9PBU3', 'P31939', 'Q13856', 'Q53S28'],
#  ['P14207', 'Q05CA5', 'Q6GTE8'],
#  ['Q1HE20', 'Q86T92', 'Q8TEG3', 'Q96FL0', 'Q96NT5'],
#  ['P15328', 'Q53EW2', 'Q6FGT8', 'Q6LC90', 'Q9UCT2'],
#  ['A4LAZ5',
#   'Q0VF45',
#   'Q5JYD9',
#   'Q5JYE0',
#   'Q9BR49',
#   'Q9UPC9',
#   'Q9UPG4',
#   'Q9UPG7',
#   'Q9Y6Q9'],
#  ['B5MDZ1', 'P29466', 'Q53EY6', 'Q6DMQ1', 'Q6GSS3', 'Q6PI75', 'Q9UCN3'],
#  ['A8K047', 'P35367', 'Q6P9E5'],
#  ['A8K846', 'B2RCZ3', 'P45452', 'Q6NWN6'],
#  ['C9IYG0', 'Q7Z5Q3', 'Q7Z5Q4', 'Q9GZU7'],
#  ['A6NK36', 'O00763', 'Q16852', 'Q1HEC1', 'Q6KE87', 'Q6KE89', 'Q6TY48'],
#  ['A8K0S3',
#   'B5BU66',
#   'B5M0B4',
#   'D3DWQ8',
#   'D3DWQ9',
#   'P45984',
#   'Q15708',
#   'Q15710',
#   'Q15711',
#   'Q8N5C5'],
#  ['B5BTZ5',
#   'B7ZLV4',
#   'D3DX88',
#   'D3DX92',
#   'P45983',
#   'Q15709',
#   'Q15712',
#   'Q15713',
#   'Q308M2'],
#  ['A6NFS3', 'A6NG28', 'B3KQ94', 'P53779', 'Q15707', 'Q49AP1'],
#  ['P52333', 'Q13259', 'Q13260', 'Q13611', 'Q8N1E8', 'Q99699', 'Q9Y6S2'],
#  ['A8K4S4', 'Q8IYV3', 'Q9NUJ5', 'Q9UHD2'],
#  ['D3DT78', 'Q14164', 'Q3B754', 'Q3KR43', 'Q5JTS6'],
#  ['P43405'],
#  ['A6NIA0', 'B4DGB2', 'Q5THN3', 'Q99461', 'Q99683'],
#  ['B4DNM4',
#   'C7G533',
#   'C7G534',
#   'C7G535',
#   'D3DTR4',
#   'J9JID1',
#   'O14630',
#   'O60446',
#   'O95083',
#   'Q96DV5',
#   'Q96GD4',
#   'Q9UQ46'],
#  ['A8K7P9',
#   'O75824',
#   'P32239',
#   'Q16144',
#   'Q92492',
#   'Q96LC6',
#   'Q9NYK7',
#   'Q9UBV1'],
#  ['P23458', 'Q59GQ2', 'Q9UD26'],
#  ['C0LZJ3', 'Q16665', 'Q53XP6', 'Q96PT9', 'Q9UPB1'],
#  ['A0AVH6', 'A8K436', 'A8K9G5', 'O15380', 'Q13946', 'Q96T72'],
#  ['B4DR68', 'D3DUC8', 'F5H897', 'O43642', 'O75235', 'Q12931', 'Q9UHL5'],
#  ['B0KZ81', 'B2R834', 'Q05655', 'Q15144', 'Q86XJ6'],
#  ['B2RE27',
#   'E1P523',
#   'O43317',
#   'O43318',
#   'O43319',
#   'Q5TDN2',
#   'Q5TDN3',
#   'Q5TDT7',
#   'Q9NTR3',
#   'Q9NZ70'],
#  ['B2R7F7',
#   'B4E1A7',
#   'Q4QZ40',
#   'Q53H04',
#   'Q53H06',
#   'Q69EZ7',
#   'Q7Z7P3',
#   'Q9UCA1',
#   'P00734'],
#  ['O43193'],
#  ['A0M8W7',
#   'B0YIU9',
#   'E9PE65',
#   'H7BXJ9',
#   'Q9BYB9',
#   'Q9BYC0',
#   'Q9BYC1',
#   'Q9UJT5',
#   'Q9ULS1',
#   'P56817'],
#  ['O75469',
#   'Q006P5',
#   'Q008C8',
#   'Q96AC7',
#   'Q9UJ22',
#   'Q9UJ23',
#   'Q9UJ24',
#   'Q9UJ25',
#   'Q9UJ26',
#   'Q9UJ27',
#   'Q9UNW4'],
#  ['A3KMC8', 'A8K2H5', 'P25105'],
#  ['A6NCG0', 'G1FFP1', 'O00329', 'O15445', 'Q5SR49'],
#  ['P14740'],
#  ['Q14832', 'Q2PNZ6', 'Q75MV4', 'Q75N17', 'Q86YG6', 'Q8TBH9'],
#  ['B1AP59', 'P15169'],
#  ['P07711', 'Q6IAV1', 'Q96QJ0'],
#  ['A1L3A5',
#   'A8MW39',
#   'B7WNW8',
#   'Q7Z3F4',
#   'Q96PS5',
#   'Q9BQF6',
#   'Q9C0F6',
#   'Q9HBT5'],
#  ['P31422'],
#  ['P70627', 'Q547B6'],
#  ['A4D1M1', 'P15085', 'Q53XU0', 'Q9BS67', 'Q9UCF2'],
#  ['O88867'],
#  ['B0YJ91', 'Q13464', 'Q2KHM4', 'Q59GZ4'],
#  ['P43235', 'Q6FHS6'],
#  ['P08912', 'Q96RG7'],
#  ['B2RDI8', 'B4DUX5', 'G3XA91', 'P50579', 'Q8NB11'],
#  ['P46720'],
#  ['P17164', 'Q642C6'],
#  ['A8K2N9', 'B4DKR9', 'P52895', 'Q14133', 'Q5SR16', 'Q7M4N1', 'Q96A71'],
#  ['P48058', 'Q86XE8'],
#  ['Q16478', 'Q8WWG8'],
#  ['D4QA03',
#   'E9PIL6',
#   'I3VM55',
#   'Q49A21',
#   'Q4G0M3',
#   'Q69YY8',
#   'Q9BVH5',
#   'Q9H7H5',
#   'Q9UK66',
#   'Q9Y2K7'],
#  ['P47820', 'Q7TMC6', 'Q8CFN1', 'Q9EQM9'],
#  ['B0QZ44',
#   'B4E3I2',
#   'F5H3T1',
#   'P41229',
#   'Q5JUX3',
#   'Q5JUX4',
#   'Q5JUX5',
#   'Q7Z5S5'],
#  ['Q8N3M8', 'Q9BZS8', 'Q9BZT0', 'Q9GZT9'],
#  ['P16109', 'Q5R344', 'Q8IVD1'],
#  ['A2TJX0', 'L0R3U5', 'L0R4T9', 'Q13887', 'Q9UHP8'],
#  ['B2R9X8', 'B7ZLF6', 'P39900', 'Q2M1L9'],
#  ['P11474', 'Q14514'],
#  ['A2VDJ2', 'B6ZGU4', 'O95718', 'Q5F0P7', 'Q5F0P8', 'Q9HCB4'],
#  ['A8K4N0',
#   'A8MU64',
#   'B7Z2J7',
#   'E9PCW2',
#   'Q05513',
#   'Q15207',
#   'Q5SYT5',
#   'Q969S4'],
#  ['A0AV49', 'B2RMV3', 'P52732', 'Q15716', 'Q5VWX0'],
#  ['B2RBD3', 'Q9H8F2', 'Q9HAS4', 'Q9H2K2'],
#  ['B4DW54', 'E7EUE5', 'P05091', 'Q03639', 'Q6IB13', 'Q6IV71'],
#  ['O95271', 'O95272', 'Q4G0F2', 'Q59FX0'],
#  ['A5D8U2', 'B2RTV1', 'Q969F8', 'Q96QG0'],
#  ['Q5QD26', 'Q8VHQ5', 'Q923Y9'],
#  ['P33259', 'P33261', 'Q8WZB1', 'Q8WZB2', 'Q9UCD4'],
#  ['P32305', 'P97936'],
#  ['F1LRH9', 'Q6RI86'],
#  ['B2R492', 'P16083', 'Q5TD04'],
#  ['P09057'],
#  ['Q4QRI7', 'Q9GZX2', 'Q9H4K8', 'Q9Y5N1'],
#  ['A8K8C8', 'Q02127', 'Q6P176'],
#  ['B0LPE4',
#   'B2R7X2',
#   'O14823',
#   'O14824',
#   'O14825',
#   'O14826',
#   'Q4JG18',
#   'Q53GA6',
#   'Q6GMT4',
#   'Q6P4D8',
#   'Q8NEQ9',
#   'Q96EC3',
#   'Q9UCZ0',
#   'Q9UCZ1',
#   'Q9UCZ2',
#   'Q9UCZ3',
#   'Q9UH95',
#   'Q9UHA1',
#   'Q9UMZ5',
#   'P07550'],
#  ['B2R9A0', 'B4DNF9', 'O00576', 'P11802', 'Q6FG61'],
#  ['A8KAF2', 'P10696', 'Q16727', 'Q53S81', 'Q96CM1'],
#  ['B2RAM5', 'B7Z5R1', 'Q9BWB6', 'P31749'],
#  ['P15207', 'Q63049'],
#  ['B2RBZ7', 'B4DFK7', 'P16152', 'Q3LHW8'],
#  ['Q9QYN6', 'Q9QYN7', 'Q9QYN8', 'Q9QYN9'],
#  ['B2RCI5', 'K7ESB3', 'L0L8N9', 'Q16853', 'Q45F94'],
#  ['B0LPE2', 'P08588', 'Q5T5Y4', 'Q9UKG7', 'Q9UKG8'],
#  ['O35433', 'Q920B3', 'Q920B4', 'Q9JLM0', 'Q9JM56', 'Q9JM57'],
#  ['F1MA51', 'Q02759'],
#  ['B4DIM0', 'B4E3P0', 'P53396', 'Q13037', 'Q9BRL0'],
#  ['P16638', 'Q497C7', 'Q8VIQ1'],
#  ['B4E1Y4',
#   'B7ZL46',
#   'F5H347',
#   'F5H7P0',
#   'O94877',
#   'Q2M3M0',
#   'Q5JUC9',
#   'Q5VYJ2',
#   'Q5VYJ3',
#   'Q9H3R0'],
#  ['O75164', 'Q5VVB1'],
#  ['Q8N1Q1'],
#  ['P42260'],
#  ['P19492'],
#  ['P19493', 'Q64241'],
#  ['D3DTF1',
#   'P42263',
#   'Q4VXD5',
#   'Q4VXD6',
#   'Q9HDA0',
#   'Q9HDA1',
#   'Q9HDA2',
#   'Q9P0H1'],
#  ['B5BU57',
#   'E1P557',
#   'H0UI48',
#   'P06241',
#   'Q16248',
#   'Q5R3A6',
#   'Q5R3A7',
#   'Q8N5D7'],
#  ['A1L457', 'A8K8N8', 'A8MXS7', 'O75460', 'Q59EE2'],
#  ['A1A4V5', 'P35462', 'Q4VBM8'],
#  ['B3KMQ3', 'P28838', 'Q6IAM6', 'Q6P0L6', 'Q9UQE3'],
#  ['B9EG79',
#   'F8W805',
#   'Q13255',
#   'Q13256',
#   'Q14757',
#   'Q14758',
#   'Q5VTF7',
#   'Q5VTF8',
#   'Q9NU10',
#   'Q9UGS9',
#   'Q9UGT0'],
#  ['O60834', 'P15086', 'Q53XJ0', 'Q96BQ8'],
#  ['Q64560'],
#  ['A8K7V2',
#   'B5MDD5',
#   'P53634',
#   'Q2HIY8',
#   'Q53G93',
#   'Q71E75',
#   'Q71E76',
#   'Q7M4N9',
#   'Q7Z3G7',
#   'Q7Z5U7',
#   'Q8WY99',
#   'Q8WYA7',
#   'Q8WYA8'],
#  ['Q63424'],
#  ['O75273',
#   'O75868',
#   'Q1ZZB8',
#   'Q6AI37',
#   'Q6UAL0',
#   'Q6ZMT2',
#   'Q6ZNJ5',
#   'Q86TI2',
#   'Q8N2J7',
#   'Q8N3F5',
#   'Q8WXD8',
#   'Q96NT8',
#   'Q9BVR3'],
#  ['P13945', 'Q4JFT4'],
#  ['B2RC38', 'Q16005', 'Q6IBA7', 'Q96J47', 'P17931'],
#  ['A7VJG6',
#   'F8W9W4',
#   'O00182',
#   'O14532',
#   'O75028',
#   'Q3B8N1',
#   'Q53FQ0',
#   'Q8WYQ7',
#   'Q9NQ58'],
#  ['P47929', 'Q6IB87'],
#  ['B2R5E8', 'P09382', 'Q9UDK5'],
#  ['A0AVK1', 'A6NDY6', 'P11217'],
#  ['A6NDQ4',
#   'B4DUB7',
#   'F5H816',
#   'O60567',
#   'O60752',
#   'O60913',
#   'P06737',
#   'Q501V9',
#   'Q641R5',
#   'Q96G82'],
#  ['E7EUT4', 'P00354', 'P04406', 'Q53X65'],
#  ['P39748'],
#  ['A6NGT4',
#   'P28715',
#   'Q5JUS4',
#   'Q5JUS5',
#   'Q7Z2V3',
#   'Q8IZL6',
#   'Q8N1B7',
#   'Q9HD59',
#   'Q9HD60'],
#  ['Q14CQ0', 'Q9UJM8', 'Q9UPZ0', 'Q9Y3I7'],
#  ['B4DRT9',
#   'O95712',
#   'P0C869',
#   'Q19KD5',
#   'Q19KD6',
#   'Q59GF9',
#   'Q8TB10',
#   'Q9UKV7'],
#  ['B6ZGU0', 'Q9UHM4', 'Q9Y5X4'],
#  ['B2R721', 'B7ZAU2', 'D3DR35', 'P14735', 'Q5T5N2'],
#  ['Q3KRD3', 'Q5KTC7'],
#  ['Q495H1', 'Q5NUL3', 'Q5VY25', 'Q5VY26', 'Q7Z605', 'Q86SM7'],
#  ['P35408', 'Q3MJ87'],
#  ['A1A4E7',
#   'B2RMP8',
#   'B7Z387',
#   'B7Z4Y6',
#   'O75090',
#   'P05186',
#   'Q2TAI7',
#   'Q59EJ7',
#   'Q5BKZ5',
#   'Q5VTG5',
#   'Q6NZI8',
#   'Q8WU32',
#   'Q9UBK0'],
#  ['A8K158', 'B3KW71', 'P09417', 'Q53F52', 'Q9H3M5'],
#  ['B3KP84', 'Q8N5Z0', 'Q9UL02'],
#  ['B2R723',
#   'B4E2V6',
#   'B7Z9G6',
#   'D3DP03',
#   'E7ER36',
#   'O43441',
#   'P25101',
#   'Q16432',
#   'Q16433',
#   'Q8TBH2'],
#  ['P11712', 'P11713', 'Q16756', 'Q16872', 'Q5VX92', 'Q6IRV8', 'Q8WW80'],
#  ['Q9EP74', 'Q9QZN9'],
#  ['A6NLM6', 'Q05193', 'Q5SYX0', 'Q5SYX2', 'Q6P3T6', 'Q86VD2'],
#  ['P11926', 'Q53TU3', 'Q6LDS9'],
#  ['P41180',
#   'Q13912',
#   'Q16108',
#   'Q16109',
#   'Q16110',
#   'Q16379',
#   'Q2M1T0',
#   'Q4PJ19'],
#  ['A0AVG9', 'B7ZLT7', 'B7ZLT8', 'F5H0A0', 'P36888', 'Q13414'],
#  ['J3KR30',
#   'O43495',
#   'Q17R58',
#   'Q4VBN5',
#   'Q4ZFV2',
#   'Q6FHI8',
#   'Q86UH4',
#   'Q9HC97'],
#  ['O43647', 'Q9P1Q2', 'Q9UIV3', 'P01375'],
#  ['A8K9Y0', 'P43088', 'Q2KHP3', 'Q6RYQ6', 'Q9P1X4'],
#  ['P10608', 'Q6LCR3'],
#  ['P26255'],
#  ['P34995', 'Q5U5U4', 'Q86UH3', 'Q86VB5', 'Q8NHB2'],
#  ['A8K7C4', 'C9J497', 'O60764', 'P06493'],
#  ['B4E2E6', 'P53582'],
#  ['O60226', 'P78536'],
#  ['A8K327', 'Q9NQE1', 'Q9UQ49'],
#  ['B2R8B8', 'P08254', 'Q3B7S0', 'Q6GRF8'],
#  ['P22894', 'Q45F99'],
#  ['Q62646', 'P35439'],
#  ['A2RUS0', 'P18089', 'Q4TUH9', 'Q53RF2', 'Q9BZK0'],
#  ['B2RXH2'],
#  ['D3DTE5', 'O00398', 'Q4VBN7', 'Q86V16'],
#  ['Q2M3F7', 'Q9BXC1'],
#  ['O95853', 'Q9UPC5'],
#  ['B2RAC7', 'O15132', 'Q502U9', 'Q6NSP5', 'Q99677'],
#  ['Q9H1C0'],
#  ['O75587', 'P43005', 'Q5VZ24', 'Q8N199', 'Q9UEW2'],
#  ['P41240', 'Q2M3N2', 'Q6FGZ6'],
#  ['P16257'],
#  ['P35355', 'Q64379', 'Q925V4'],
#  ['C5HF20', 'O43192', 'P30518', 'Q3MJD3', 'Q9UCV9'],
#  ['O09022',
#   'O09023',
#   'O09024',
#   'P27732',
#   'Q01542',
#   'Q62691',
#   'Q62815',
#   'Q63491',
#   'Q63492'],
#  ['P37288'],
#  ['Q62731', 'Q63684', 'Q63921'],
#  ['A0AVQ3', 'B2RMT0', 'O95950', 'P41597', 'Q4VBL2'],
#  ['O00199', 'Q12884', 'Q53TP5', 'Q86Z29', 'Q99998', 'Q9UID4'],
#  ['B4DQE9', 'P43004', 'Q14417', 'Q541G6', 'U3KQQ4'],
#  ['A5YW33', 'O15443', 'Q07343', 'Q13945', 'Q5TEK4', 'Q5TEK5', 'Q5TEK6'],
#  ['A8K5M2', 'D3DP53', 'Q96AN1', 'Q96KP2', 'P42574'],
#  ['P32198', 'P97780', 'Q6IMZ4'],
#  ['B4DWC9', 'D3DV05', 'P25774', 'Q5T5I0', 'Q6FHS5', 'Q9BUG3'],
#  ['Q549C7', 'Q6IB96', 'Q9UBZ6', 'Q9UCM9', 'P02766'],
#  ['P07195'],
#  ['B4DKQ2',
#   'B7Z5E3',
#   'D3DQY3',
#   'F8W819',
#   'P00338',
#   'Q53G53',
#   'Q6IBM7',
#   'Q6ZNV1',
#   'Q9UDE8',
#   'Q9UDE9'],
#  ['P19020', 'P70647'],
#  ['P22734'],
#  ['B3KXE1', 'P35236', 'Q53XK4', 'Q5SXQ0', 'Q5SXQ1', 'Q9BV05'],
#  ['O95136', 'Q86UN8'],
#  ['D6W612', 'O95977'],
#  ['P48147', 'Q8N6D4'],
#  ['P00797', 'Q6FI38', 'Q6T5C2'],
#  ['B2R9S3', 'P21918', 'Q8NEQ8'],
#  ['B0M0J7', 'P21917', 'Q7Z7Q5', 'Q8NGM5'],
#  ['A8K0I3',
#   'B0ZBD1',
#   'B0ZBD2',
#   'B0ZBD4',
#   'B0ZBD5',
#   'B0ZBD6',
#   'B0ZBD8',
#   'B0ZBD9',
#   'O60451',
#   'P35348',
#   'Q13675',
#   'Q13729',
#   'Q4VBM7',
#   'Q6RUJ4',
#   'Q6RUJ5',
#   'Q6RUJ7',
#   'Q6RUJ8',
#   'Q6RUJ9',
#   'Q96RE8',
#   'Q9UD63',
#   'Q9UD67'],
#  ['P49137', 'Q5SY30', 'Q5SY41', 'Q8IYD6']]
