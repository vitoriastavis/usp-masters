# %%
from collections import Counter

protein_counts = Counter()

with open("top_metabolites") as f:
    for line in f:
        parts = [x.strip() for x in line.strip().split(",")]
        proteins = parts[1:]  # ignora metabolito
        protein_counts.update(proteins)

# ver as mais comuns
print(protein_counts)
# Out:
# Counter({'THRA': 9, 'PDE4B': 9, 'HTT': 9, 'ERBB4': 9, 'EP300': 9, 'DRD2': 9, 'GRM5': 9, 'ESR2': 9, 'CTSB': 9, 'MAP3K5': 9, 'RARB': 9, 'FGFR3': 9, 'CHRM1': 9, 'RHOA': 5, 'FEN1': 4, 'GRIK1': 4, 'CPB2': 3, 'P4HTM': 3, 'FOS': 3, 'EID2': 3, 'SLC1A2': 2, 'GRIK2': 1, 'F3': 1, 'FADS1': 1, 'SENP7': 1, 'AIP': 1, 'ST6GAL1': 1})
